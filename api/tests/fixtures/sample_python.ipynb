# %% [markdown]
# # Sample Python Notebook
#
# This is a test notebook for characterization tests.

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
def add(a, b):
    return a + b

add(40, 2)
# Out:
# 42

# %% [markdown]
# ## Section 2
#
# More content here.
